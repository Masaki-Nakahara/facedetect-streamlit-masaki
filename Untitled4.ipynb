# %%
# APIリクエストに必要なライブラリ
import requests
# URL＋クエリパラメータ
url = 'http://weather.livedoor.com/forecast/webservice/json/v1?city=400040'
# APIリクエストを送信
tenki_data = requests.get(url).json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/requests/models.py:910, in Response.json(self, **kwargs)
#     909 try:
# --> 910     return complexjson.loads(self.text, **kwargs)
#     911 except JSONDecodeError as e:
#     912     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     913     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 4)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Input In [1], in <module>
#       4 url = 'http://weather.livedoor.com/forecast/webservice/json/v1?city=400040'
#       5 # APIリクエストを送信
# ----> 6 tenki_data = requests.get(url).json()
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/requests/models.py:917, in Response.json(self, **kwargs)
#     915     raise RequestsJSONDecodeError(e.message)
#     916 else:
# --> 917     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: [Errno Expecting value]
# <!DOCTYPE html>
# <html lang="ja">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WPKMK2X');</script>
# <!-- End Google Tag Manager -->
# <meta http-equiv="X-UA-Compatible" content="IE=EmulateIE9">
# <meta charset="utf-8">
# <title>livedoor</title>
# <meta name="description" content="LINE株式会社が運営するポータルサイト。速報性に加え独自の切り口を誇る「ライブドアニュース」、日本最大のブログサービス「ライブドアブログ」ほか、厳選した情報をお届けします。">
# <meta name="keywords" content="ライブドア,ポータル,ニュース,ブログ,livedoor,portal,LINE,LD">
# <meta property="og:site_name" content="livedoor">
# <meta property="og:image" content="https://image.livedoor.com/img/top/17/livedoor_small.png">
# <meta name="verify-v1" content="1bivxaxGrLBSoWSu7qAOa0M36HWHyewW+8YqCFDlBZQ=">
#
# <link rel="shortcut icon" href="/img/ie9/favicon.ico">
#
# <style type="text/css">
#     @import url('/css/17/ldtop.4.6.css');
# </style>
#
# <script src="/js/jquery.min.4.6.js"></script>
# <script src="/js/jquery.cookie.4.6.js"></script>
# <script src="/js/ldtop-ver.4.6.js"></script>
# <script src="/js/ldtop.4.6.js"></script>
# <script src="/js/weather.4.6.js"></script>
# <script src="/js/abtest/rewrite.js"></script>
# <!--[if lt IE 9]><script src="/js/html5shiv.4.6.js"></script><![endif]-->
#
# <link rel="canonical" href="https://www.livedoor.com/">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/top.xml" title="RSS主要トピックス">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/dom.xml" title="RSS国内トピックス">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/int.xml" title="RSS海外トピックス">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/eco.xml" title="RSS IT 経済トピックス">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/ent.xml" title="RSS芸能トピックス">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/spo.xml" title="RSSスポーツトピックス">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/rss/summary/52.xml" title="RSS映画新着記事">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/gourmet.xml" title="RSSグルメトピックス">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/love.xml" title="RSS女子トピックス">
# <link rel="alternate" type="application/rss+xml" href="https://news.livedoor.com/topics/rss/trend.xml" title="RSSトレンドトピックス">
#
# <!-- UniversalAnalytics -->
# <script>
# function GAProxy(){
#     this.push = function(args){
#         if(args.length > 5){
#             throw "invalid argument length";
#         }
#         var eventName = args[0];
#         var category = args[1];
#         var action = args[2];
#         var label = args[3];
#         var value = args[4];
#         if(eventName !== '_trackEvent'){ // ignore
#             return;
#         }
#         if(typeof(action) === "undefined"){
#             alert("actionが設定されていません");
#             return;
#         }
#         var params = ["send", "event", category, action, label, value];
#         var filtered_params = params.filter(function(e){
#             return typeof(e) !== "undefined";
#         });
#         if(typeof(ga) !== "undefined"){
#             ga.apply(window, filtered_params);
#         }
#     };
# }
# var _gaq = new GAProxy();
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-1661457-18', 'auto');
#   ga('send', 'pageview');
# </script>
#
#
#
# <script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
#
# <script>
# googletag.defineSlot('/21627555768/livedoor_TOP/PC/main_middle_left', [300, 250], 'div-gpt-ad-1523251167609-0').addService(googletag.pubads());googletag.defineSlot('/21627555768/livedoor_TOP/PC/main_middle_right', [300, 250], 'div-gpt-ad-1523251186864-0').addService(googletag.pubads());googletag.defineSlot('/21627555768/livedoor_TOP/PC/sbu_1st', [300, 250], 'div-gpt-ad-1523251221036-0').addService(googletag.pubads());
#
#     googletag.pubads().setTargeting('env', ["production"]);
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().collapseEmptyDivs();
#     googletag.enableServices();
#   });
# </script>
#
# </head>
# <body>
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WPKMK2X"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#
#
#
# <header>
#     <section id="common-header">
#         <div class="common-header-inner">
#             <h1><a href="/" title="livedoor" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', 'ロゴ','']);">livedoor</a></h1>
#             <ul>
#                 <li><a href="https://news.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', 'ナビゲーション','ニュース']);">ニュース</a></li>
#                 <li><a href="https://blog.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', 'ナビゲーション','ブログ']);">ブログ</a></li>
#                 <li><a href="https://livedoor.blogcms.jp/member/" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', 'ナビゲーション','ブログを書く']);">ブログを書く</a></li>
#                 <li class="menu_open"><a>全て<span>▼</span></a>
#                     <aside id="slide-box">
#                         <a class="btn_close">全て<span>▲</span></a>
#                         <ul>
#                             <li><a href="http://girls.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', 'ナビゲーション/全て','Peachy']);">Peachy</a></li>
#                             <li><a href="http://www.kstyle.com/" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', 'ナビゲーション/全て','Kstyle']);">Kstyle</a></li>
#                             <li><a href="http://blogroll.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', 'ナビゲーション/全て','相互RSS']);">相互RSS</a></li>
#                         </ul>
#                     </aside><!--/#slide-box-->
#                 </li>
#             </ul>
#             <div id="member">
#         <ul>
#         <li><span class="guestname">ゲストさん</span></li>
#         <li><a href="https://member.livedoor.com/register/email?.sv=top" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', '未ログイン','ユーザー登録']);">ユーザー登録</a></li>
#         <li><a href="http://member.livedoor.com/login/?.sv=top" onclick="_gaq.push(['_trackEvent', 'PC_ヘッダー', '未ログイン','ログイン']);">ログイン</a></li>
#     </ul>
#     </div>
#
#         </div>
#     </section>
# </header>
#
# <section id="container">
#
#
#
#
# <aside id="side-bar">
#
#     <section class="side-premium">
#     <script type="text/javascript"><!--
#     google_ad_client = "ca-pub-6988676431156825";
#     /* top_1st_300×250_b */
#     google_ad_slot = "5580519287";
#     google_ad_width = 300;
#     google_ad_height = 250;
#     //-->
#     </script>
#     <!--
#     <script type="text/javascript" src="//pagead2.googlesyndication.com/pagead/show_ads.js">
#     </script>
# <!-- /21627555768/livedoor_TOP/PC/sbu_1st -->
# <div id='div-gpt-ad-1523251221036-0'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1523251221036-0'); });
# </script>
# </div>
#
#     </section>
#
#     <aside id="weather-setting">
#         <a class="btn-close">設定</a>
#         <dl>
#             <dt>天気エリア</dt>
#             <dd>
#                 <form id="weather-form" onsubmit="return false">
#                     <ul>
#                         <li>
#                             <label id="area1-label">都道府県</label>
#                             <select name="pref_id" id="select-area1"></select>
#                             <span class="area1-select"></span>
#                         </li>
#                         <li>
#                             <label id="area1-labe2">エリア</label>
#                             <select name="city_id" id="select-area2"></select>
#                             <span class="area2-select"></span>
#                         </li>
#                     </ul>
#                     <button type="submit">決定</button>
#                 </form>
#             </dd>
#         </dl>
#     </aside>
#
#
#
#
#
#     <section class="side-theme side-column">
#
#     <h2>注目のテーマ</h2>
#     <ul>
#         <li>
#             <a class="adjustment" href="https://news.livedoor.com/%E3%82%A6%E3%82%AF%E3%83%A9%E3%82%A4%E3%83%8A%E5%8D%B1%E6%A9%9F/topics/keyword/33656/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','ウクライナ危機']);">
#                 <img src="https://image.news.livedoor.com/newsimage/stf/c/b/cbe07_1675_81d639c81d55d58548812695e5fb10bc-cs.jpg?v=20220702155209" alt="ウクライナ危機" height="80" />
#
#             </a>
#             <h3><a href="https://news.livedoor.com/%E3%82%A6%E3%82%AF%E3%83%A9%E3%82%A4%E3%83%8A%E5%8D%B1%E6%A9%9F/topics/keyword/33656/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','ウクライナ危機']);">ウクライナ危機</a></h3>
#             <ul>
#                 <li><a id="topics_2458691" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22435662/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','ウクライナ危機/記事リンク']);">安保理 ロシアと対話に転換か</a><span class="new">new</span></li>
#                 <li><a id="topics_2458510" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22431300/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','ウクライナ危機/記事リンク']);">残忍な戦争 直面する外国人部隊</a></li>
#                 <li><a id="topics_2458080" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22428048/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','ウクライナ危機/記事リンク']);">オデーサにロシアのミサイル攻撃</a></li>
#             </ul>
#         </li>
#         <li>
#             <a class="adjustment" href="https://news.livedoor.com/%E5%8C%97%E6%9C%9D%E9%AE%AE%E3%83%9F%E3%82%B5%E3%82%A4%E3%83%AB%E5%95%8F%E9%A1%8C/topics/keyword/27491/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','北朝鮮ミサイル問題']);">
#                 <img src="https://image.news.livedoor.com/newsimage/stf/7/8/78bf0_1641_b6106880_0fac97e0-cs.jpg?v=20220702124901" alt="北朝鮮ミサイル問題" height="80" />
#
#             </a>
#             <h3><a href="https://news.livedoor.com/%E5%8C%97%E6%9C%9D%E9%AE%AE%E3%83%9F%E3%82%B5%E3%82%A4%E3%83%AB%E5%95%8F%E9%A1%8C/topics/keyword/27491/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','北朝鮮ミサイル問題']);">北朝鮮ミサイル問題</a></h3>
#             <ul>
#                 <li><a id="topics_2458652" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22435007/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','北朝鮮ミサイル問題/記事リンク']);">北がG7非難声明に反発「冒涜だ」</a><span class="new">new</span></li>
#                 <li><a id="topics_2451775" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22379914/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','北朝鮮ミサイル問題/記事リンク']);">北が核実験せぬよう中国が努力か</a></li>
#                 <li><a id="topics_2448086" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22350533/" onclick="_gaq.push(['_trackEvent', 'サイドカラム', '注目のテーマ','北朝鮮ミサイル問題/記事リンク']);">北 核実験とさらなる挑発行為か</a></li>
#             </ul>
#         </li>
#     </ul>
#     <script type="text/javascript">
#     var rand_topics_title_hash = {};
#
#     var topics_ab_title = new Array();
#     var target_topics = {};
#
#
#
#
#     topics_ab_title = randomAdv(target_topics);
#     rand_topics_title_hash['topics_2458691'] = topics_ab_title;
#
#     var topics_ab_title = new Array();
#     var target_topics = {};
#
#
#
#
#     topics_ab_title = randomAdv(target_topics);
#     rand_topics_title_hash['topics_2458510'] = topics_ab_title;
#
#     var topics_ab_title = new Array();
#     var target_topics = {};
#
#
#
#
#     topics_ab_title = randomAdv(target_topics);
#     rand_topics_title_hash['topics_2458080'] = topics_ab_title;
#
#     var topics_ab_title = new Array();
#     var target_topics = {};
#
#
#
#
#     topics_ab_title = randomAdv(target_topics);
#     rand_topics_title_hash['topics_2458652'] = topics_ab_title;
#
#     var topics_ab_title = new Array();
#     var target_topics = {};
#
#
#
#
#     topics_ab_title = randomAdv(target_topics);
#     rand_topics_title_hash['topics_2451775'] = topics_ab_title;
#
#     var topics_ab_title = new Array();
#     var target_topics = {};
#
#
#
#
#     topics_ab_title = randomAdv(target_topics);
#     rand_topics_title_hash['topics_2448086'] = topics_ab_title;
#
#
#     rewrite_topics_titles(rand_topics_title_hash);
#     $(".rewrite_ab").css("visibility","visible");
#     </script>
#
#     </section>
#
#
#
# </aside><!-- /#side-bar -->
#
# <section id="main-column">
#
#     <section class="news-topics">
#         <ul>
#                   <li><a href="https://news.livedoor.com/topics/category/main/" class="topics_tab" id="topics_category_default" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','主要/ニュースタブ']);">主要</a></li>
#                   <li><a href="https://news.livedoor.com/topics/category/dom/" class="topics_tab" id="topics_category_smart_dom" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','国内/ニュースタブ']);">国内</a></li>
#                   <li><a href="https://news.livedoor.com/topics/category/world/" class="topics_tab" id="topics_category_41" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','海外/ニュースタブ']);">海外</a></li>
#                   <li class="wide"><a href="https://news.livedoor.com/topics/category/eco/" class="topics_tab" id="topics_category_11" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','経済/ニュースタブ']);">IT 経済</a></li>
#                   <li class="wide"><a href="https://news.livedoor.com/topics/category/sports/" class="topics_tab" id="topics_category_smart_spo" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','スポーツ/ニュースタブ']);">スポーツ</a></li>
#                   <li><a href="https://news.livedoor.com/topics/category/ent/" class="topics_tab" id="topics_category_smart_ent" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','エンタメ/ニュースタブ']);">芸能</a></li>
#                   <li class="wide"><a href="https://news.livedoor.com/topics/category/gourmet/" class="topics_tab" id="topics_category_gourmet" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','グルメ/ニュースタブ']);">グルメ</a></li>
#                   <li><a href="https://news.livedoor.com/topics/category/love/" class="topics_tab" id="topics_category_love" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','恋愛/ニュースタブ']);">女子</a></li>
#                   <li class="wide"><a href="https://news.livedoor.com/topics/category/trend/" class="topics_tab" id="topics_category_trend" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースタブ','トレンド/ニュースタブ']);">トレンド</a></li>
#         </ul>
#     <div id="news-topics">
#
# <div id="newstopicsbox">
#
#     <figure id="topics-image">
#         <a id="headline_link_498640" href="https://news.livedoor.com/topics/detail/22474494/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">
#
#             <img id="headline_img_3_498640" src="https://image.news.livedoor.com/newsimage/stf/8/e/8e2b6_456_6e5bb32199164be28b4e812df456898d.jpg" alt="" title="" width="300" onMouseDown="return false;" onSelectStart="return false;" oncontextmenu="return false;" galleryimg="no" />
#
#         </a>
#         <figcaption><a id="headline_498640" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474494/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">カロリーゼロ理論 栄養士が抗議</a></figcaption>
#     </figure >
#
#     <ol>
#           <li><a id="topics_3223021" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474610/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">乗務中女性の胸触った車掌を解雇</a>            <span class="new">新着</span>        </a></li>
#           <li><a id="topics_3222986" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474484/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">銃撃 奈良県警が午後6時から会見</a>        </a></li>
#           <li><a id="topics_3223002" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474411/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">関心低下のコロナ 医師の違和感</a>        </a></li>
#           <li><a id="topics_3223003" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474167/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">奈良医大「クレーム殺到はデマ」</a>            <span class="new">新着</span>        </a></li>
#           <li><a id="topics_3223009" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474587/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">核シェルター購入 秘密にする訳</a>            <span class="new">新着</span>        </a></li>
#           <li><a id="topics_3222952" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474325/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">安倍元首相弔問に小泉元首相の姿</a>        </a></li>
#           <li><a id="topics_3223013" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474172/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">沖縄で異常気象「川にもサメ」</a>            <span class="new">新着</span>        </a></li>
#           <li><a id="topics_3222941" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473657/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">立民代表 小沢一郎氏の発言注意</a>        </a></li>
#           <li><a id="topics_3222917" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473892/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">容疑者 県内有数の進学校出身</a>        </a></li>
#           <li><a id="topics_3222964" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474238/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">圭さん眞子さん 外見に「変化」?</a>        </a></li>
#           <li><a id="topics_3222910" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474047/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">安倍氏銃撃が影響? 海外で逮捕も</a>        </a></li>
#           <li><a id="topics_3222851" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473510/" class="tx" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','主要']);">大谷の特大19号直後の行動に騒然</a>        </a></li>
#     </ol>
#
#     <p class="detail-link"><a href="https://news.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニューストピックス','ニューストップ']);">一覧</a></p>
#
# </div><!--/#newstopicsbox-->
# <script type="text/javascript">
# var rand_topics_title_hash = {};
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3223021'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3222986'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3223002'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3223003'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3223009'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3222952'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3223013'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3222941'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3222917'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3222964'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3222910'] = topics_ab_title;
#
# var topics_ab_title = new Array();
# var target_topics = {};
#
#
#
#
# topics_ab_title = randomAdv(target_topics);
# rand_topics_title_hash['topics_3222851'] = topics_ab_title;
#
#
# var rand_headline_title_hash = {};
# var rand_headline_category_hash = {};
# var rand_headline_image_hash = {};
# var rand_headline_link_hash = {};
# var rand_headline_link_category_hash = {};
# var headline_ab_title = new Array();
# var target_headline = {};
#
#
#
#
# headline_ab_title = randomAdv(target_headline);
# rand_headline_image_hash['headline_img_1_498640'] = headline_ab_title;
# rand_headline_image_hash['headline_img_2_498640'] = headline_ab_title;
# rand_headline_image_hash['headline_img_3_498640'] = headline_ab_title;
# rand_headline_title_hash['headline_498640'] = headline_ab_title;
# rand_headline_category_hash['headline_498640'] = 1;
# rand_headline_link_hash['headline_link_498640'] = headline_ab_title;
# rand_headline_link_category_hash['headline_link_498640'] = 1;
#
# rewrite_headline_titles(rand_headline_title_hash,rand_headline_category_hash);
# rewrite_headline_link(rand_headline_link_hash,rand_headline_link_category_hash);
# rewrite_titles_image(rand_headline_image_hash);
# rewrite_topics_titles(rand_topics_title_hash);
# $(".rewrite_ab").css("visibility","visible");
# </script>
#
#     </div>
# </section><!-- /#blog-topics -->
#
# <form id="userParam">
#     <input type="hidden" name="topics_category_saved" value="default">
#     <input type="hidden" name="topics_category" value="default">
# </form>
# <script>
#     var ApiKey = 'g83e0PIcZDZE7cD99BqHuawUJIHfKjA6';
#     $(function() {
#       var topics_category = $('#userParam [name=topics_category_saved]').val();
#       var id = "topics_category_" + topics_category;
#       if (topics_category != $('#userParam [name=topics_category]').val()) {
#         $("#" + id).trigger("click", [ true ]);
#       }
#       $("#" + id).addClass('active');
#     });
# </script>
#
# <section class="news-ranking">
#     <h2>ニュースランキング</h2>
#
# <div id="topics-ranking">
# <ol class="headline">
# <li class="ranking-1">
#     <a id="article_link_2463387" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473225/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','「家族が入信、金を納めて生活苦に」容疑の男、安倍氏に一方的恨みか']);">
#     <span class="num">1</span>
#     <figure class="topics-ranking-photo">
#         <div class="ranking-photo"><img id="article_img_2463387" class="rewrite_ab" src="https://image.news.livedoor.com/newsimage/stf/2/9/29bd6_1509_a716b0f8_f0ccc638-cs.jpg?v=20220709122135" alt="銃撃容疑者 家族が入信し生活苦" height="108" onMouseDown="return false;" onSelectStart="return false;" oncontextmenu="return false;" galleryimg="no" /></div>
#         <figcaption id="article_2463387" class="rewrite_ab" >銃撃容疑者 家族が入信し生活苦</figcaption>
#     </figure>
#     </a>
# </li>
# <li class="ranking-2">
#     <a id="article_link_2463412" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473837/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','TBS井上貴博アナ　安倍元首相めぐる報道で感じたジレンマ「私自身もつらくなる瞬間があった」']);">
#     <span class="num">2</span>
#     <figure class="topics-ranking-photo">
#         <div class="ranking-photo"><img id="article_img_2463412" class="rewrite_ab" src="https://image.news.livedoor.com/newsimage/stf/6/d/6d2f9_929_ac56f586_d78aaf7a-cs.jpg?v=20220709174040" alt="井上アナ 安倍氏報道めぐる葛藤" height="108" onMouseDown="return false;" onSelectStart="return false;" oncontextmenu="return false;" galleryimg="no" /></div>
#         <figcaption id="article_2463412" class="rewrite_ab" >井上アナ 安倍氏報道めぐる葛藤</figcaption>
#     </figure>
#     </a>
# </li>
# <li class="ranking-3">
#     <a id="article_link_2463423" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474366/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','【速報】東京　新たに9716人の新型コロナ感染を確認']);">
#     <span class="num">3</span>
#     <figure class="topics-ranking-photo">
#         <div class="ranking-photo"><img id="article_img_2463423" class="rewrite_ab" src="https://image.news.livedoor.com/newsimage/stf/4/5/45a5f_1641_16bb81f4_ae99eefa-s.jpg" alt="東京 新たに9716人の感染を確認" height="108" onMouseDown="return false;" onSelectStart="return false;" oncontextmenu="return false;" galleryimg="no" /></div>
#         <figcaption id="article_2463423" class="rewrite_ab" >東京 新たに9716人の感染を確認</figcaption>
#     </figure>
#     </a>
# </li>
# <li class="ranking-4">
#     <a id="article_link_2463405" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474066/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','ひろゆき氏、日本は「本気でやろうとする人を止めるセキュリティーになっていないことが多い」　安倍晋三元首相銃撃事件に言及']);">
#     <span class="num">4</span>
#     <figure class="topics-ranking-photo">
#         <div class="ranking-photo"><img id="article_img_2463405" class="rewrite_ab" src="https://image.news.livedoor.com/newsimage/stf/5/f/5f914_456_eb379c813e5a8d849ae07d1252c76de9-cs.jpg?v=20220709162123" alt="ひろゆき氏 銃撃巡り安全面指摘" height="108" onMouseDown="return false;" onSelectStart="return false;" oncontextmenu="return false;" galleryimg="no" /></div>
#         <figcaption id="article_2463405" class="rewrite_ab" >ひろゆき氏 銃撃巡り安全面指摘</figcaption>
#     </figure>
#     </a>
# </li>
# <li class="ranking-5">
#     <a id="article_link_2463342" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473450/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','菅前首相　安倍氏は「本当に強いリーダーだった」　病院駆け付け絶句、涙も']);">
#     <span class="num">5</span>
#     <figure class="topics-ranking-photo">
#         <div class="ranking-photo"><img id="article_img_2463342" class="rewrite_ab" src="https://image.news.livedoor.com/newsimage/stf/f/5/f59a2_1718_000cda6d3c09d68a70f38023506a2251-s.jpg" alt="菅前首相 安倍氏遺体と対面し涙" height="108" onMouseDown="return false;" onSelectStart="return false;" oncontextmenu="return false;" galleryimg="no" /></div>
#         <figcaption id="article_2463342" class="rewrite_ab" >菅前首相 安倍氏遺体と対面し涙</figcaption>
#     </figure>
#     </a>
# </li>
# </ol><ol>
# <li class="ranking-6">
#     <a id="article_link_22473531" class="rewrite_ab" href="https://news.livedoor.com/article/detail/22473531/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','大手5紙、異例の全く同じ見出しで話題　「安倍元首相　撃たれ死亡」一面で報じる']);">
#     <span class="num">6</span>
#     <span id="article_22473531" class="rewrite_ab" >大手5紙、異例の全く同じ見出しで話題　...</span>
#     </a>
# </li>
# <li class="ranking-7">
#     <a id="article_link_2463254" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473018/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','6月29日の大火球、落下した可能性　葛飾区付近に隕石約50グラム']);">
#     <span class="num">7</span>
#     <span id="article_2463254" class="rewrite_ab" >葛飾区付近に隕石落下した可能性</span>
#     </a>
# </li>
# <li class="ranking-8">
#     <a id="article_link_2463313" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473297/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','九州修学旅行中の高校生３人、サッカーの走力で容疑者追い込んだ']);">
#     <span class="num">8</span>
#     <span id="article_2463313" class="rewrite_ab" >修学旅行中の3人 容疑者追い込む</span>
#     </a>
# </li>
# <li class="ranking-9">
#     <a id="article_link_2463359" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22473161/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','安倍元首相の銃撃現場、SAT元隊員が分析――「警備やりづらい場所」「非常に手薄」　規制なし、尾行なし…ナゼ？']);">
#     <span class="num">9</span>
#     <span id="article_2463359" class="rewrite_ab" >元SAT 銃撃現場は警備やりづらい</span>
#     </a>
# </li>
# <li class="ranking-10">
#     <a id="article_link_2463426" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22474353/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','兄はロッテ朗希　大船渡の佐々木怜希が初戦敗退「夏だけ違う雰囲気」　27球ノースイングで5四球']);">
#     <span class="num">10</span>
#     <span id="article_2463426" class="rewrite_ab" >朗希の弟・佐々木怜希が初戦登場</span>
#     </a>
# </li>
# </ol><ol>
# <li class="ranking-11">
#     <a id="article_link_22473985" class="rewrite_ab" href="https://news.livedoor.com/article/detail/22473985/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','金爆・鬼龍院翔が「大リーグボール養成ギプス」装着して始球式「外して投げれば150キロ」']);">
#     <span class="num">11</span>
#     <span id="article_22473985" class="rewrite_ab" >金爆・鬼龍院翔が「大リーグボール養成...</span>
#     </a>
# </li>
# <li class="ranking-12">
#     <a id="article_link_22474024" class="rewrite_ab" href="https://news.livedoor.com/article/detail/22474024/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','徳島知事「リスク告知するので問題ない」　食事券「紙くず」化']);">
#     <span class="num">12</span>
#     <span id="article_22474024" class="rewrite_ab" >徳島知事「リスク告知するので問題ない...</span>
#     </a>
# </li>
# <li class="ranking-13">
#     <a id="article_link_2463294" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22472842/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','ＡＥＤ使用も救命かなわず　安倍氏銃撃']);">
#     <span class="num">13</span>
#     <span id="article_2463294" class="rewrite_ab" >安倍氏銃撃 AED作動しない状態</span>
#     </a>
# </li>
# <li class="ranking-14">
#     <a id="article_link_22473782" class="rewrite_ab" href="https://news.livedoor.com/article/detail/22473782/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','１枚100万円超！ヴィンテージＴシャツが高騰し続ける裏事情']);">
#     <span class="num">14</span>
#     <span id="article_22473782" class="rewrite_ab" >１枚100万円超！ヴィンテージＴシャツが...</span>
#     </a>
# </li>
# <li class="ranking-15">
#     <a id="article_link_2463249" class="rewrite_ab" href="https://news.livedoor.com/topics/detail/22471479/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ニュースランキング','岸田首相、若手時代の安倍元首相との写真投稿…「多くの時間をともにした良き友人でした」']);">
#     <span class="num">15</span>
#     <span id="article_2463249" class="rewrite_ab" >若手時代の安倍氏写真 首相投稿</span>
#     </a>
# </li>
# </ol>
# </div>
# <script type="text/javascript">
# var rand_article_title_hash = {};
# var rand_article_title_link_hash = {};
# var rand_article_title_image_hash = {};
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463387'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463387'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463387'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463412'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463412'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463412'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463423'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463423'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463423'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463405'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463405'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463405'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463342'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463342'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463342'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_22473531'] = article_ab_title;
# rand_article_title_link_hash['article_link_22473531'] = article_ab_title;
# rand_article_title_image_hash['article_img_22473531'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463254'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463254'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463254'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463313'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463313'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463313'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463359'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463359'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463359'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463426'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463426'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463426'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_22473985'] = article_ab_title;
# rand_article_title_link_hash['article_link_22473985'] = article_ab_title;
# rand_article_title_image_hash['article_img_22473985'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_22474024'] = article_ab_title;
# rand_article_title_link_hash['article_link_22474024'] = article_ab_title;
# rand_article_title_image_hash['article_img_22474024'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463294'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463294'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463294'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_22473782'] = article_ab_title;
# rand_article_title_link_hash['article_link_22473782'] = article_ab_title;
# rand_article_title_image_hash['article_img_22473782'] = article_ab_title;
#
# var article_ab_title = new Array();
# var target_article = {};
#
#
#
#
# article_ab_title = randomAdv(target_article);
# rand_article_title_hash['article_2463249'] = article_ab_title;
# rand_article_title_link_hash['article_link_2463249'] = article_ab_title;
# rand_article_title_image_hash['article_img_2463249'] = article_ab_title;
#
# rewrite_titles_figcaption_span(rand_article_title_hash);
# rewrite_topics_link(rand_article_title_link_hash);
# rewrite_titles_image_alt(rand_article_title_image_hash);
# $(".rewrite_ab").css("visibility","visible");
# </script>
#
# </section>
#
# <!-- /21627555768/livedoor_TOP/PC/main_middle_left -->
# <div id='div-gpt-ad-1523251167609-0'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1523251167609-0'); });
# </script>
# </div>
# <!-- /21627555768/livedoor_TOP/PC/main_middle_right -->
# <div id='div-gpt-ad-1523251186864-0'>
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1523251186864-0'); });
# </script>
# </div>
# </section>
#
# <section class="blog-news">
#     <h2>ブログ編集部の「推し」</h2>
#     <div id="blog-topics-box" class="boxbody">
#
#
# <a href="http://blog.livedoor.jp/hogehoge2929/archives/1080458150.html" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','昭和の香りがする\u0022謎の駅前食堂\u0022']);" target="_blank">
#     <figure>
#         <img src="https://resize.blogsys.jp/66b1759b1d3db10355ae4f1b43ef6d305742ee29/trim2/7x43_19p_298x184/https://livedoor.blogimg.jp/hogehoge2929/imgs/6/6/66100e77.jpg" width="300" alt="昭和の香りがする&quot;謎の駅前食堂&quot;" title="昭和の香りがする&quot;謎の駅前食堂&quot;" />
#         <figcaption>昭和の香りがする&quot;謎の駅前食堂&quot;</figcaption>
#     </figure>
# </a>
#
# <ol id="blog-article-list">
#     <li><a href="http://sakuraeye.blog.jp/archives/56790054.html" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','親子で\u0022ハマった\u00223Dプリンター']);" target="_blank">親子で&quot;ハマった&quot;3Dプリンター</a></li>
#     <li><a href="https://bikemen.livedoor.biz/archives/1816253.html" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','3年ぶりに\u0022久留米の夏の風物詩\u0022']);" target="_blank">3年ぶりに&quot;久留米の夏の風物詩&quot;</a></li>
#     <li><a href="https://ninjago.blog.jp/archives/29053913.html" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','あおむけで\u0022うなされる\u0022ワンコ']);" target="_blank">あおむけで&quot;うなされる&quot;ワンコ</a></li>
#     <li><a href="http://blog.livedoor.jp/chikuwabu1027/archives/56784988.html" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','買ってきてもらった函館のお菓子']);" target="_blank">買ってきてもらった函館のお菓子</a></li>
#     <li><a href="http://blog.livedoor.jp/nikukyuupuyo/archives/29086239.html" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','ダイソーの糸で「気軽に編もう」']);" target="_blank">ダイソーの糸で「気軽に編もう」</a></li>
#     <li><a href="http://owacon.livedoor.biz/archives/1883804.html" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','最近やっているゲームを教えて']);" target="_blank">最近やっているゲームを教えて</a></li>
#     <li><a href="http://lightmellow.livedoor.biz/archives/52349496.html" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','泰葉の\u0022天賦の才\u0022が分かる楽曲']);" target="_blank">泰葉の&quot;天賦の才&quot;が分かる楽曲</a></li>
# </ol>
#
# <p class="detail-link"><a href="https://blog.livedoor.com/news/" onclick="_gaq.push(['_trackEvent', 'メインカラム', 'ブログニュース','ブログニュース一覧']);" target="_blank">もっと見る</a></p>
#
#     </div>
# </section>
#
#
#
# <section class="blog-ranking">
#     <h2>ブログランキング</h2>
#
# <div id="blog-ranking">
#     <ol>
#
#         <li value="1" class="ranking-1"><a title="【悲報】メルカリで安倍元首相銃撃事件の号外新聞が大量出品される" href="http://jin115.com/archives/52349871.html" class="value1" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【悲報】メルカリで安倍元首相銃撃事件の号外新聞が']);" target="_blank"><span class="num">1</span>【悲報】メルカリで安倍元首相銃撃事件の号外新聞が大量出品さ...</a><span class="blog-name">オレ的ゲーム速報＠...</span></li>
#
#
#         <li value="2" class="ranking-2"><a title="【画像】安倍氏暗殺犯の自作銃がヤバイと話題に" href="http://blog.livedoor.jp/dqnplus/archives/2017811.html" class="value2" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【画像】安倍氏暗殺犯の自作銃がヤバイと話題に']);" target="_blank"><span class="num">2</span>【画像】安倍氏暗殺犯の自作銃がヤバイと話題に</a><span class="blog-name">痛いニュース(ﾉ∀`...</span></li>
#
#
#         <li value="3" class="ranking-3"><a title="女美容師「彼女います？」ワイ「(意地悪したろｗ)死にました…」→ まさかの展開・・・" href="http://world-fusigi.net/archives/10079653.html" class="value3" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','女美容師「彼女います？」ワイ「(意地悪したろｗ)死']);" target="_blank"><span class="num">3</span>女美容師「彼女います？」ワイ「(意地悪したろｗ)死にました…...</a><span class="blog-name">不思議.net</span></li>
#
#
#         <li value="4" class="ranking-4"><a title="占い、別の星座を見ても大体当たってる" href="https://mamekichimameko.blog.jp/archives/86443354.html" class="value4" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','占い、別の星座を見ても大体当たってる']);" target="_blank"><span class="num">4</span>占い、別の星座を見ても大体当たってる</a><span class="blog-name">まめきちまめこニー...</span></li>
#
#
#         <li value="5" class="ranking-5"><a title="【涙腺崩壊】天国の安倍晋三さんからネット民にメッセージが届く…5ch民号泣…（動画あり）" href="http://www.akb48matomemory.com/archives/1080278633.html" class="value5" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【涙腺崩壊】天国の安倍晋三さんからネット民にメッ']);" target="_blank"><span class="num">5</span>【涙腺崩壊】天国の安倍晋三さんからネット民にメッセージが届...</a><span class="blog-name">NEWSまとめもりー｜...</span></li>
#
#
#         <li value="6" class="ranking-6"><a title="各国から安倍元首相を惜しむ声…米国半旗を掲げる・英国女王陛下から天皇陛下に弔慰、各国首脳からも" href="https://hamusoku.com/archives/10538382.html" class="value6" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','各国から安倍元首相を惜しむ声…米国半旗を掲げる・']);" target="_blank"><span class="num">6</span>各国から安倍元首相を惜しむ声…米国半旗を掲げる・英国女王陛...</a><span class="blog-name">ハムスター速報</span></li>
#
#
#         <li value="7" class="ranking-7"><a title="【酷すぎ】ギリシャのニュース番組、『MGS』小島秀夫監督を安倍元首相銃撃事件の犯人だと誤報してしまう…原因はネットの悪ノリ" href="http://blog.esuteru.com/archives/9905893.html" class="value7" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【酷すぎ】ギリシャのニュース番組、『MGS』小島秀']);" target="_blank"><span class="num">7</span>【酷すぎ】ギリシャのニュース番組、『MGS』小島秀夫監督を安...</a><span class="blog-name">はちま起稿</span></li>
#
#
#         <li value="8" class="ranking-8"><a title="打率1割だけど60本ホームラン打つキャッチャー←欲しい？" href="http://blog.livedoor.jp/nanjstu/archives/59492927.html" class="value8" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','打率1割だけど60本ホームラン打つキャッチャー←欲']);" target="_blank"><span class="num">8</span>打率1割だけど60本ホームラン打つキャッチャー←欲しい？</a><span class="blog-name">なんじぇいスタジア...</span></li>
#
#
#         <li value="9" class="ranking-9"><a title="【悲報】安倍銃撃犯、『趣味』を暴露されてしまう。これって…" href="http://onecall2ch.com/archives/10080676.html" class="value9" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【悲報】安倍銃撃犯、『趣味』を暴露されてしまう。']);" target="_blank"><span class="num">9</span>【悲報】安倍銃撃犯、『趣味』を暴露されてしまう。これって…</a><span class="blog-name">わんこーる速報！</span></li>
#
#
#         <li value="10" class="ranking-10"><a title="【画像】看護師♀「若いときにクリアしておくべきことは…」←100万いいねｗｗｗ" href="http://news4vip.livedoor.biz/archives/52454381.html" class="value10" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【画像】看護師♀「若いときにクリアしておくべきこ']);" target="_blank"><span class="num">10</span>【画像】看護師♀「若いときにクリアしておくべきことは…」←...</a><span class="blog-name">【2ch】ニュー速ク...</span></li>
#
#     </ol><ol>
#
#
#         <li value="11" class="ranking-11"><a title="宗教に母親が騙されて自己破産、そのせいで大学中退し逆恨みで安倍晋三銃殺" href="http://blog.livedoor.jp/nwknews/archives/5945078.html" class="value11" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','宗教に母親が騙されて自己破産、そのせいで大学中退']);" target="_blank"><span class="num">11</span>宗教に母親が騙されて自己破産、そのせいで大学中退し逆恨みで...</a><span class="blog-name">哲学ニュースnwk</span></li>
#
#
#         <li value="12" class="ranking-12"><a title="『タイトルが秀逸な小説』を挙げてけ" href="http://bipblog.com/archives/5799410.html" class="value12" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','『タイトルが秀逸な小説』を挙げてけ']);" target="_blank"><span class="num">12</span>『タイトルが秀逸な小説』を挙げてけ</a><span class="blog-name">BIPブログ</span></li>
#
#
#         <li value="13" class="ranking-13"><a title="ゲームデザイナー小島秀夫さん、ギリシャのニュースで安倍氏襲撃の容疑者にされてしまう" href="http://blog.livedoor.jp/rock1963roll/archives/5354864.html" class="value13" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','ゲームデザイナー小島秀夫さん、ギリシャのニュース']);" target="_blank"><span class="num">13</span>ゲームデザイナー小島秀夫さん、ギリシャのニュースで安倍氏襲...</a><span class="blog-name">なんJ PRIDE</span></li>
#
#
#         <li value="14" class="ranking-14"><a title="台風で浸水した家から出られなくなった見知らぬ犬を救い出した男性" href="https://karapaia.com/archives/52313917.html" class="value14" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','台風で浸水した家から出られなくなった見知らぬ犬を']);" target="_blank"><span class="num">14</span>台風で浸水した家から出られなくなった見知らぬ犬を救い出した...</a><span class="blog-name">カラパイア</span></li>
#
#
#         <li value="15" class="ranking-15"><a title="誕生日会に誰も来なかった件【14】" href="https://www.yagov30.com/archives/33397827.html" class="value15" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','誕生日会に誰も来なかった件【14】']);" target="_blank"><span class="num">15</span>誕生日会に誰も来なかった件【14】</a><span class="blog-name">ヤゴヴのマンガ劇場</span></li>
#
#
#         <li value="16" class="ranking-16"><a title="先輩ワイ「ネジは対角で締めろと言ってるだろ！！！！」" href="http://www.oumaga-times.com/archives/1080673045.html" class="value16" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','先輩ワイ「ネジは対角で締めろと言ってるだろ！！！']);" target="_blank"><span class="num">16</span>先輩ワイ「ネジは対角で締めろと言ってるだろ！！！！」</a><span class="blog-name">おうまがタイムズ</span></li>
#
#
#         <li value="17" class="ranking-17"><a title="【連載】【第115話】勘違いお絵描きオタクが美大を受験したレポ漫画" href="https://kaerudx.com/archives/29678311.html" class="value17" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【連載】【第115話】勘違いお絵描きオタクが美大を']);" target="_blank"><span class="num">17</span>【連載】【第115話】勘違いお絵描きオタクが美大を受験したレ...</a><span class="blog-name">カエルDXのオタ活日...</span></li>
#
#
#         <li value="18" class="ranking-18"><a title="【悲報】奈良医科大学にクレームが殺到する" href="http://blog.livedoor.jp/news23vip/archives/5945080.html" class="value18" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【悲報】奈良医科大学にクレームが殺到する']);" target="_blank"><span class="num">18</span>【悲報】奈良医科大学にクレームが殺到する</a><span class="blog-name">VIPPERな俺</span></li>
#
#
#         <li value="19" class="ranking-19"><a title="あの日失くした人形は【最終話】" href="https://babareo.site/archives/15524891.html" class="value19" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','あの日失くした人形は【最終話】']);" target="_blank"><span class="num">19</span>あの日失くした人形は【最終話】</a><span class="blog-name">世にも奇妙ななんか...</span></li>
#
#
#         <li value="20" class="ranking-20"><a title="【悲報】日本の記者のレベル、低すぎる・・・" href="http://inutomo11.com/archives/29139648.html" class="value20" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','【悲報】日本の記者のレベル、低すぎる・・・']);" target="_blank"><span class="num">20</span>【悲報】日本の記者のレベル、低すぎる・・・</a><span class="blog-name">なんJクエスト</span></li>
#
#
#     </ol>
#     <p class="detail-link"><a href="https://blog.livedoor.com/ranking/" onclick="_gaq.push(['_trackEvent', 'メインカラム', '注目ブログランキング','一覧/注目ブログランキング']);" target="_blank">もっと見る</a></p>
# </div>
#
# </section>
#
# </section><!-- /#main-column -->
#
# </section><!-- /#container -->
#
# <footer>
#     <div class="footer-inner">
#         <dl class="content-list">
#             <dt>コンテンツ一覧</dt>
# <ul>
# <li><a href="https://news.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'コンテンツ一覧','ニュース']);">ニュース</a></li>
# <li><a href="http://www.kstyle.com/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'コンテンツ一覧','韓流ニュース']);">Kstyle</a></li>
# </ul>
#
# <ul>
# <li><a href="https://blog.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'コンテンツ一覧','ブログ']);">ブログ</a></li>
# <li><a href="http://baito.line.me/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'コンテンツ一覧','バイト探し']);">バイト探し</a></li>
# </ul>
#
# <ul>
# <li><a href="http://blogroll.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'コンテンツ一覧','Blog Roll']);">相互RSS</a></li>
# <li><a href="http://travel.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'コンテンツ一覧','格安航空券比較']);">格安航空券比較</a></li>
# </ul>
#
# <ul>
# <li><a href="http://a-hikkoshi.com/livedoor/index.html" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'コンテンツ一覧','引越し見積もり']);">引越し見積もり</a></li>
# <li><a href="http://girls.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'コンテンツ一覧','女性']);">Peachy</a></li>
# </ul>
#
#
#             </dd>
#         </dl>
#         <div class="common-footer">
#             <ul>
#                 <li><a href="https://www.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'フッターリンク','livedoorトップ']);">livedoorトップ</a></li>
#                 <li><a href="https://linecorp.com/career/position/list" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'フッターリンク','採用情報']);">採用情報</a></li>
#                 <li><a href="https://www.linebiz.com/jp/service/media-service/livedoor-news/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'フッターリンク','広告掲載']);">広告掲載</a></li>
#                 <li><a href="https://www.livedoor.com/rules/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'フッターリンク','利用規約']);">利用規約</a></li>
#                 <li><a href="https://www.livedoor.com/privacy/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'フッターリンク','プライバシーポリシー']);">プライバシーポリシー</a></li>
#                 <li><a href="https://linecorp.com" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'フッターリンク','会社概要']);">会社概要</a></li>
#                 <li><a href="http://linecorp.com/ja/pr/news/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'フッターリンク','プレスリリース']);">プレスリリース</a></li>
#                 <li><a href="https://help.livedoor.com/" onclick="_gaq.push(['_trackEvent', 'PC_フッター', 'フッターリンク','ヘルプ']);">ヘルプ</a></li>
#             </ul>
#             <p>&copy; LINE Corporation</p>
#         </div><!--/common-footer-->
#     </div><!--/footer-inner-->
# </footer>
# <aside id="close_layer"></aside>
# <script>
# $(function(){
#   $('.menu_open a').click(function(){
#     $('#slide-box').css('display','block');
#     $('aside#close_layer').css('z-index','5');
#   });
#   $('#slide-box .btn_close').click(function(){
#     $(this).parents('#slide-box').css('display','none');
#     $('aside#close_layer').css('z-index','-1');
#   });
# });
# </script>
# </body></html>
# : 4
